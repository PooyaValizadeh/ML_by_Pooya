# %%
import pandas as pd
import numpy as np
import plotly as pl

# %%
df = pd.read_csv("titanic.csv")
df.sample(5)
# Out:
#      pclass  survived                                          name     sex  \
# 18        1         1                         Bazzani, Miss. Albina  female
# 746       3         1                      Daly, Mr. Eugene Patrick    male
# 149       1         1  Harris, Mrs. Henry Birkhardt (Irene Wallach)  female
# 768       3         0                            Denkoff, Mr. Mitto    male
# 126       1         0                   Futrelle, Mr. Jacques Heath    male
#
#       age  sibsp  parch  ticket     fare cabin embarked     boat  body  \
# 18   32.0      0      0   11813  76.2917   D15        C        8   NaN
# 746  29.0      0      0  382651   7.7500   NaN        Q  13 15 B   NaN
# 149  35.0      1      0   36973  83.4750   C83        S        D   NaN
# 768   NaN      0      0  349225   7.8958   NaN        S      NaN   NaN
# 126  37.0      1      0  113803  53.1000  C123        S      NaN   NaN
#
#                             home.dest
# 18                                NaN
# ...

# %%
from plotly.express import box
box(x = 'age',data_frame = df)

# %%
df1= df[(df.age < 66.1)]
df1
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301       3         0                             Youseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
import plotly.express as ex
ex.violin(x = "age" , data_frame = df)
