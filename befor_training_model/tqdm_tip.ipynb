# %%
from tqdm import tqdm 
import time

# %%
for khamenei in tqdm([1,2,3,4,5,6,7,8,9,5,6,36,2]):
    time.sleep(1)
# Out:
# 100%|██████████████████████████████████████████| 13/13 [00:13<00:00,  1.00s/it]
